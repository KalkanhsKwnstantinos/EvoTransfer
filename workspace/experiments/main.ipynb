# %% [markdown]
# Load your data and necessary imports

# %%
from src.methods import preparation_tf

preparation_tf()
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1779203946.177669     269 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1779203946.231069     269 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1779203946.231111     269 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.

# %%
#from src.ga import run_evolution
from src.loaders import load_fashion_mnist, load_mnist

fashion_set = load_fashion_mnist()
mnist_set = load_mnist()
# Out:
# I0000 00:00:1779203946.669655     269 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1779203946.669692     269 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1779203946.669701     269 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1779203946.799942     269 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1779203946.799977     269 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# ...

# %% [markdown]
# Set up gene space

# %%
from src.genespace import setup_gs

#Genespace parameters: lr, batch_size, dropout, kernel, conv_layers, conv_size, dense_layers, dense_size

#preparing parameter space
genespace = setup_gs(lr=(1e-4, 1e-2), batch_size = 64, dropout_rate = (0.0, 0.5), kernel=[3, 5], conv_layers=[1, 2, 3], conv_size=(16,128), dense_layers=[1,2], dense_size=(64, 256))
print(genespace.config.values())
# Out:
# dict_values([(0.0001, 0.01), 64, (0.0, 0.5), [3, 5], [1, 2, 3], (16, 128), [1, 2], (64, 256), None, None])

# %%
from src.ga import run_evolution

dataset = mnist_set
pop = run_evolution(genespace, dataset, pop_size=20, generations=15, matepb=0.5, mutpb=0.1)
pop = run_evolution(genespace, dataset, pop_size=20, generations=15, matepb=0.5, mutpb=0.1)
pop = run_evolution(genespace, dataset, pop_size=20, generations=15, matepb=0.5, mutpb=0.1)
pop = run_evolution(genespace, dataset, pop_size=20, generations=15, matepb=0.5, mutpb=0.1)
pop = run_evolution(genespace, dataset, pop_size=20, generations=15, matepb=0.5, mutpb=0.1)
print(pop)
# Out:
# Generation 0
# W0000 00:00:1779007059.490558  284542 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1779007059.510341  284542 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1779007059.510775  284542 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1779007059.511143  284542 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1779007059.511469  284542 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1779007059.516617  284542 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1779007059.519822  284542 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1779007059.520669  284542 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# ...

# %%
from src.ga import run_evolution

dataset = fashion_set

pop = run_evolution(genespace, dataset, pop_size=20, generations=15, matepb=0.5, mutpb=0.1)
# Out:
# Generation 0
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# Cell In[4], line 5
#       1 from src.ga import run_evolution
#       3 dataset = fashion_set
# ----> 5 pop = run_evolution(genespace, dataset, pop_size=20, generations=15, matepb=0.5, mutpb=0.1)
#
# File /workspace/experiments/src/ga.py:41, in run_evolution(genespace, dataset, pop_size, generations, matepb, mutpb, prev_pop)
#      37 population = prev_pop if prev_pop else toolbox.population(n=pop_size)
#      39 print("Generation 0")
# ---> 41 fitnesses = list(map(toolbox.evaluate, population))
#      42 for ind, fit in zip(population, fitnesses):
#      43     ind.fitness.values = fit
#
# File /workspace/experiments/src/fitness.py:53, in evaluate_individual(ind, dataset)
#      51 queue = ctx.Queue()
#      52 p = ctx.Process(target=eval_worker, args=(ind, dataset, queue))
# ---> 53 p.start()
#      54 p.join()
# ...

# %%
dataset = mnist_set
pop_2 = run_evolution(genespace, dataset, pop_size=20, generations=15, matepb=0.5, mutpb=0.1, prev_pop=pop)

# %%
print(len(pop))
# Out:
# 20
