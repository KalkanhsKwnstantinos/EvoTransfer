# %%
# %%time
from src.ga import run_evolution
from keras.datasets import mnist

dataset = mnist.load_data()
pop = run_evolution(dataset, pop_size=20, generations=10)

print(pop)
# Out:
# Generation 1
# {'lr': 0.000785660328741641, 'batch': 64, 'filters': [128, 128]}
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1773923032.272513   59523 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1773923032.381282   59523 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1773923032.381354   59523 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1773923032.401351   59523 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# ...

# %%
# %%time
from src.ga import run_evolution
from keras.datasets import fashion_mnist

dataset = fashion_mnist.load_data()
pop = run_evolution(dataset, pop_size=20, generations=10)

print(pop)
# Out:
# Generation 1
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1773935474.044861  174831 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1773935474.128450  174831 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1773935474.128485  174831 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1773935474.149376  174831 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# ...

# %%
from src.model import build_model
from keras.datasets import mnist
import tensorflow as tf

lr = 0.0006243931135250005
filters = [128, 32]
batch = 16
dataset = mnist.load_data()
(x_train, y_train), (x_val, y_val) = dataset

model = build_model(filters, lr) 

model.fit(
    x_train, y_train,
    epochs=3,        # keep small for GA
    batch_size=batch,
    verbose=0
)

model.summary()

model.evaluate(x=x_val,y=y_val)

del model
tf.keras.backend.clear_session()
# Out:
# ...
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1773914431.697412     148 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1773914431.898069     148 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1773914431.898108     148 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1773914431.920489     148 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# ...
